# %%
import os
import numpy as np

# %%
data_path = "train_data"

# %%
lables = os.listdir(data_path)
categorys = np.arange(len(lables))
categorys_dict = dict(zip(lables,categorys))

print(lables)
print(categorys_dict)
# Out:
# ['Avishka', 'Chanuka', 'Dasun', 'Dulanga', 'Iduwara', 'Isuru', 'Kavindu']
# {'Avishka': np.int64(0), 'Chanuka': np.int64(1), 'Dasun': np.int64(2), 'Dulanga': np.int64(3), 'Iduwara': np.int64(4), 'Isuru': np.int64(5), 'Kavindu': np.int64(6)}

# %%
import cv2



for lable in lables:
    imgs_path = os.path.join(data_path,lable)
    imgs = os.listdir(imgs_path)
    for img in imgs:
        img_path = os.path.join(imgs_path,img)
        img = cv2.imread(img_path)

        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
